# %%
from dash import Dash as JupyterDash
from layout import layout
from callback import callback_reg

# Start the app
app = JupyterDash(__name__)

# Layout 
app.layout = layout

# Callbacks
callback_reg(app)

# Run app
app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
